# %%
class Solution:
    def defangIPaddr(self, address: str) -> str:
        return address.replace(".", "[.]")

# %%
sol = Solution()                     # create object
sol.defangIPaddr("1.1.1.1")          # call function.
# Out:
# '1[.]1[.]1[.]1'

# %%
sol.defangIPaddr("255.100.50.0")
# Out:
# '255[.]100[.]50[.]0'
